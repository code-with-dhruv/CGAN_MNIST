# %%
from keras.datasets.mnist import load_data
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Concatenate
from matplotlib import pyplot as plt

# %%
(trainX, trainy), (testX, testy) = load_data()

for i in range(25):
	plt.subplot(5, 5, 1 + i)
	plt.axis('off')
	plt.imshow(trainX[i])
plt.show()

# %%
from tensorflow.keras.layers import Input, Embedding, Dense, Reshape, Concatenate, Conv2DTranspose, LeakyReLU

def enhance_generator(latent_dim, n_classes=10):
    # Label input
    in_label = Input(shape=(1,))
    li = Embedding(n_classes, 50)(in_label)
    
   
    n_nodes = 128 * 7 * 7  # Adjusted to match later concatenation
    li = Dense(n_nodes)(li)
    li = Reshape((7, 7, 128))(li)
    
  
    in_lat = Input(shape=(latent_dim,))
    
    
    n_nodes = 128 * 7 * 7
    gen = Dense(n_nodes)(in_lat)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Reshape((7, 7, 128))(gen)
    
    
    merge = Concatenate()([gen, li])
    

    gen = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(merge)
    gen = LeakyReLU(alpha=0.2)(gen)
    
   
    gen = Conv2DTranspose(1, (4, 4), strides=(2, 2), padding='same', activation='tanh')(gen)
    
    # Define model
    model = Model([in_lat, in_label], gen)
    
    return model

# %%
def enhance_discriminator(in_shape=(28, 28, 1), n_classes=10):
    in_label = Input(shape=(1,))
    li = Embedding(n_classes, 100)(in_label)

    n_nodes = in_shape[0] * in_shape[1] * in_shape[2]
    li = Dense(n_nodes)(li)
    li = Reshape(in_shape)(li)

    in_image = Input(shape=in_shape)
    merge = Concatenate()([in_image, li])

    fe = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(merge)  # Increase filters
    fe = LeakyReLU(alpha=0.2)(fe)

    fe = Conv2D(256, (3, 3), strides=(2, 2), padding='same')(fe)  # Increase filters
    fe = LeakyReLU(alpha=0.2)(fe)

    fe = Flatten()(fe)
    fe = Dropout(0.4)(fe)

    out_layer = Dense(1, activation='sigmoid')(fe)

    model = Model([in_image, in_label], out_layer)
    opt = Adam(lr=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
def define_gan(g_model, d_model):
	d_model.trainable = False  
	gen_noise, gen_label = g_model.input  
	gen_output = g_model.output  #32x32x3
    
	
	gan_output = d_model([gen_output, gen_label])
	# define gan model as taking noise and label and outputting a classification
	model = Model([gen_noise, gen_label], gan_output)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %%
def load_real_samples():
	
	(trainX, trainy), (_, _) = load_data()  #mnist
	X = trainX.astype('float32')
	
	X = (X - 127.5) / 127.5   
	return [X, trainy]

# %%
def generate_real_samples(dataset, n_samples):
	
	images, labels = dataset  
	
	ix = randint(0, images.shape[0], n_samples)
	
	X, labels = images[ix], labels[ix]
	
	y = ones((n_samples, 1))  
	return [X, labels], y

# %%
def generate_latent_points(latent_dim, n_samples, n_classes=10):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)

	z_input = x_input.reshape(n_samples, latent_dim)
	labels = randint(0, n_classes, n_samples)
	return [z_input, labels]

# %%
def generate_fake_samples(generator, latent_dim, n_samples):
	
	z_input, labels_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	images = generator.predict([z_input, labels_input])
	# create class labels
	y = zeros((n_samples, 1)) 
	return [images, labels_input], y

# %%
global d;d=[]
global d2;d2=[]

# %%
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
	bat_per_epo = int(dataset[0].shape[0] / n_batch)
	half_batch = int(n_batch / 2)  
	for i in range(n_epochs):
		
		
		for j in range(bat_per_epo):
			
			[X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)

           
			d_loss_real, _ = d_model.train_on_batch([X_real, labels_real], y_real)
            
			[X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
			
			d_loss_fake, _ = d_model.train_on_batch([X_fake, labels], y_fake)
            
            
			[z_input, labels_input] = generate_latent_points(latent_dim, n_batch)
            
           
			y_gan = ones((n_batch, 1))
            
			g_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
			# Print losses on this batch
			
			print('Epoch>%d, Batch%d/%d, d1=%.3f, d2=%.3f g=%.3f' %
				(i+1, j+1, bat_per_epo, d_loss_real, d_loss_fake, g_loss))
			d.append(d_loss_real)
			d2.append(g_loss)
		g_model.save('mnist_conditional_generator3_epochs.h5')

# %%
latent_dim = 100
# create the discriminator

d_model = enhance_discriminator()
# create the generator
g_model = enhance_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=10)
# Out:
# c:\Users\dhruv\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch1/468, d1=0.701, d2=0.696 g=0.691
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch2/468, d1=0.508, d2=0.701 g=0.686
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch3/468, d1=0.382, d2=0.711 g=0.676
# 2/2 [==============================] - 0s 10ms/step
# Epoch>1, Batch4/468, d1=0.277, d2=0.727 g=0.662
# 2/2 [==============================] - 0s 10ms/step
# Epoch>1, Batch5/468, d1=0.192, d2=0.748 g=0.644
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch6/468, d1=0.139, d2=0.774 g=0.622
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch7/468, d1=0.099, d2=0.801 g=0.606
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch8/468, d1=0.083, d2=0.824 g=0.593
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch9/468, d1=0.076, d2=0.838 g=0.585
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch10/468, d1=0.075, d2=0.847 g=0.585
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch11/468, d1=0.076, d2=0.846 g=0.594
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch12/468, d1=0.086, d2=0.832 g=0.606
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch13/468, d1=0.097, d2=0.818 g=0.627
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch14/468, d1=0.106, d2=0.790 g=0.646
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch15/468, d1=0.112, d2=0.764 g=0.672
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch16/468, d1=0.120, d2=0.741 g=0.692
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch17/468, d1=0.115, d2=0.721 g=0.722
# 2/2 [==============================] - 0s 10ms/step
# Epoch>1, Batch18/468, d1=0.108, d2=0.688 g=0.765
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Bat
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch73/468, d1=0.035, d2=0.036 g=4.047
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch74/468, d1=0.076, d2=0.052 g=3.612
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch75/468, d1=0.066, d2=0.064 g=3.830
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch76/468, d1=0.054, d2=0.050 g=3.971
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch77/468, d1=0.089, d2=0.061 g=3.611
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch78/468, d1=0.057, d2=0.058 g=3.643
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch79/468, d1=0.068, d2=0.057 g=3.775
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch80/468, d1=0.071, d2=0.050 g=3.596
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch81/468, d1=0.064, d2=0.085 g=3.864
# 2/2 [==============================] - 0s 25ms/step
# Epoch>1, Batch82/468, d1=0.064, d2=0.064 g=3.839
# 2/2 [==============================] - 0s 25ms/step
# Epoch>1, Batch83/468, d1=0.153, d2=0.192 g=3.820
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch84/468, d1=0.137, d2=0.118 g=3.674
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch85/468, d1=0.103, d2=0.239 g=3.984
# 2/2 [==============================] - 0s 28ms/step
# Epoch>1, Batch86/468, d1=0.362, d2=0.515 g=3.958
# 2/2 [==============================] - 0s 25ms/step
# Epoch>1, Batch87/468, d1=0.495, d2=0.537 g=3.417
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch88/468, d1=0.628, d2=0.854 g=3.362
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch89/468, d1=0.560, d2=0.620 g=3.393
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch90/468, d1=0.221, d2=0.192 g=3.124
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch91/468, d1=0.121, d2=0.253 g=3.396
# 2/2 [==============================] - 0s 30ms/step
# Epoch>1, Batch92/468, d1=0.154, d2=0.161 g=3.137
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch93/468, d1=0.089, d2=0.140 g=3.200
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch94/468, d1=0.104, d2=0.131 g=3.180
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch95/468, d1=0.064, d2=0.085 g=3.221
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch96/468, d1=0.073, d2=0.100 g=3.286
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch97/468, d1=0.126, d2=0.147 g=3.187
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch98/468, d1=0.068, d2=0.086 g=3.417
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch99/468, d1=0.086, d2=0.084 g=3.182
# 2/2 [==============================] - 0s 25ms/step
# Epoch>1, Batch100/468, d1=0.067, d2=0.101 g=3.394
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch101/468, d1=0.173, d2=0.144 g=3.092
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch102/468, d1=0.076, d2=0.102 g=3.480
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch103/468, d1=0.092, d2=0.072 g=3.409
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch104/468, d1=0.093, d2=0.107 g=3.276
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch105/468, d1=0.139, d2=0.146 g=3.345
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch106/468, d1=0.138, d2=0.123 g=3.440
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch107/468, d1=0.162, d2=0.141 g=3.227
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch108/468, d1=0.143, d2=0.183 g=3.529
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch109/468, d1=0.252, d2=0.239 g=3.532
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch110/468, d1=0.152, d2=0.120 g=3.670
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch111/468, d1=0.224, d2=0.422 g=4.556
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch112/468, d1=0.563, d2=0.380 g=3.693
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch113/468, d1=0.222, d2=0.273 g=4.628
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch114/468, d1=0.379, d2=0.370 g=3.759
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch115/468, d1=0.362, d2=0.322 g=4.092
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch116/468, d1=0.521, d2=0.437 g=4.265
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch117/468, d1=0.646, d2=0.358 g=3.200
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch118/468, d1=0.221, d2=0.354 g=4.432
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch119/468, d1=0.484, d2=0.321 g=3.646
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch120/468, d1=0.417, d2=0.427 g=3.555
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch121/468, d1=0.218, d2=0.301 g=3.958
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch122/468, d1=0.367, d2=0.364 g=3.906
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch123/468, d1=0.345, d2=0.321 g=3.649
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch124/468, d1=0.201, d2=0.090 g=3.295
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch125/468, d1=0.228, d2=0.398 g=3.888
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch126/468, d1=0.367, d2=0.188 g=3.570
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch127/468, d1=0.157, d2=0.135 g=3.492
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Bat
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch354/468, d1=0.210, d2=0.148 g=3.749
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch355/468, d1=0.092, d2=0.150 g=3.672
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch356/468, d1=0.240, d2=0.139 g=3.507
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch357/468, d1=0.251, d2=0.304 g=3.981
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch358/468, d1=0.254, d2=0.138 g=4.266
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch359/468, d1=0.308, d2=0.236 g=3.662
# 2/2 [==============================] - 0s 31ms/step
# Epoch>1, Batch360/468, d1=0.182, d2=0.162 g=3.605
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch361/468, d1=0.224, d2=0.186 g=3.914
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch362/468, d1=0.260, d2=0.201 g=3.908
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch363/468, d1=0.185, d2=0.119 g=3.842
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch364/468, d1=0.159, d2=0.114 g=3.694
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch365/468, d1=0.151, d2=0.159 g=3.504
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch366/468, d1=0.123, d2=0.160 g=3.915
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch367/468, d1=0.204, d2=0.128 g=3.940
# 2/2 [==============================] - 0s 29ms/step
# Epoch>1, Batch368/468, d1=0.217, d2=0.124 g=3.498
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch369/468, d1=0.128, d2=0.227 g=4.011
# 2/2 [==============================] - 0s 25ms/step
# Epoch>1, Batch370/468, d1=0.353, d2=0.129 g=3.572
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch371/468, d1=0.169, d2=0.172 g=3.583
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch372/468, d1=0.168, d2=0.173 g=4.043
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch373/468, d1=0.193, d2=0.180 g=4.394
# 2/2 [==============================] - 0s 28ms/step
# Epoch>1, Batch374/468, d1=0.308, d2=0.141 g=3.957
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch375/468, d1=0.172, d2=0.130 g=3.835
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch376/468, d1=0.200, d2=0.103 g=3.384
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch377/468, d1=0.094, d2=0.178 g=3.761
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch378/468, d1=0.162, d2=0.132 g=4.401
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch379/468, d1=0.119, d2=0.073 g=3.862
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch380/468, d1=0.165, d2=0.113 g=3.599
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch381/468, d1=0.196, d2=0.256 g=3.643
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch382/468, d1=0.134, d2=0.151 g=4.367
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch383/468, d1=0.142, d2=0.096 g=4.130
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch384/468, d1=0.144, d2=0.173 g=4.025
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch385/468, d1=0.104, d2=0.056 g=3.795
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch386/468, d1=0.111, d2=0.153 g=4.244
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch387/468, d1=0.074, d2=0.090 g=4.482
# 2/2 [==============================] - 0s 30ms/step
# Epoch>1, Batch388/468, d1=0.115, d2=0.113 g=4.493
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch389/468, d1=0.198, d2=0.090 g=3.920
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch390/468, d1=0.090, d2=0.205 g=4.089
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch391/468, d1=0.050, d2=0.091 g=4.949
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch392/468, d1=0.128, d2=0.065 g=4.391
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch393/468, d1=0.069, d2=0.079 g=4.440
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch394/468, d1=0.125, d2=0.089 g=4.572
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch395/468, d1=0.120, d2=0.205 g=4.876
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch396/468, d1=0.166, d2=0.050 g=4.607
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch397/468, d1=0.104, d2=0.056 g=4.111
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch398/468, d1=0.047, d2=0.086 g=4.436
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch399/468, d1=0.093, d2=0.104 g=4.398
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch400/468, d1=0.125, d2=0.061 g=4.194
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch401/468, d1=0.108, d2=0.133 g=4.275
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch402/468, d1=0.217, d2=0.122 g=4.415
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch403/468, d1=0.053, d2=0.066 g=4.580
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch404/468, d1=0.133, d2=0.095 g=4.313
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch405/468, d1=0.074, d2=0.056 g=4.111
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch406/468, d1=0.169, d2=0.130 g=4.218
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch407/468, d1=0.184, d2=0.114 g=4.145
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch408/468, d1=0.122, d2=0.091 g=4.208
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch409/468, d1=0.054, d2=0.089 g=4.543
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch410/468, d1=0.086, d2=0.032 g=4.262
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch411/468, d1=0.134, d2=0.094 g=3.856
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch412/468, d1=0.175, d2=0.132 g=4.189
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch413/468, d1=0.087, d2=0.047 g=4.463
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch414/468, d1=0.106, d2=0.069 g=4.172
# 2/2 [==============================] - 0s 12ms/step
# Epoch>1, Batch415/468, d1=0.055, d2=0.035 g=4.189
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch416/468, d1=0.168, d2=0.081 g=3.789
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch417/468, d1=0.105, d2=0.149 g=4.523
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch418/468, d1=0.104, d2=0.027 g=4.366
# 2/2 [==============================] - 0s 14ms/step
# Epoch>1, Batch419/468, d1=0.059, d2=0.033 g=4.087
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch420/468, d1=0.047, d2=0.078 g=4.239
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch421/468, d1=0.091, d2=0.050 g=4.034
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch422/468, d1=0.171, d2=0.103 g=3.898
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch423/468, d1=0.159, d2=0.065 g=3.654
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch424/468, d1=0.154, d2=0.091 g=3.683
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch425/468, d1=0.092, d2=0.084 g=3.873
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch426/468, d1=0.227, d2=0.086 g=4.081
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch427/468, d1=0.210, d2=0.090 g=3.929
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch428/468, d1=0.188, d2=0.082 g=4.164
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch429/468, d1=0.034, d2=0.034 g=4.263
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch430/468, d1=0.107, d2=0.081 g=3.963
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch431/468, d1=0.192, d2=0.091 g=3.820
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch432/468, d1=0.148, d2=0.106 g=4.181
# 2/2 [==============================] - 0s 30ms/step
# Epoch>1, Batch433/468, d1=0.190, d2=0.079 g=4.117
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch434/468, d1=0.086, d2=0.089 g=4.245
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch435/468, d1=0.198, d2=0.078 g=4.014
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch436/468, d1=0.149, d2=0.140 g=4.434
# 2/2 [==============================] - 0s 18ms/step
# Epoch>1, Batch437/468, d1=0.144, d2=0.080 g=4.083
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch438/468, d1=0.108, d2=0.093 g=4.369
# 2/2 [==============================] - 0s 11ms/step
# Epoch>1, Batch439/468, d1=0.159, d2=0.091 g=3.732
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch440/468, d1=0.115, d2=0.136 g=4.328
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch441/468, d1=0.114, d2=0.058 g=4.238
# 2/2 [==============================] - 0s 13ms/step
# Epoch>1, Batch442/468, d1=0.343, d2=0.087 g=3.437
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch443/468, d1=0.097, d2=0.110 g=4.147
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch444/468, d1=0.104, d2=0.061 g=4.408
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch445/468, d1=0.087, d2=0.066 g=4.704
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch446/468, d1=0.172, d2=0.067 g=4.310
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch447/468, d1=0.134, d2=0.111 g=4.560
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch448/468, d1=0.069, d2=0.047 g=4.405
# 2/2 [==============================] - 0s 29ms/step
# Epoch>1, Batch449/468, d1=0.060, d2=0.061 g=4.872
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch450/468, d1=0.111, d2=0.050 g=4.283
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch451/468, d1=0.161, d2=0.080 g=4.272
# 2/2 [==============================] - 0s 23ms/step
# Epoch>1, Batch452/468, d1=0.081, d2=0.091 g=4.408
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch453/468, d1=0.189, d2=0.105 g=3.988
# 2/2 [==============================] - 0s 20ms/step
# Epoch>1, Batch454/468, d1=0.065, d2=0.063 g=4.187
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch455/468, d1=0.064, d2=0.068 g=3.794
# 2/2 [==============================] - 0s 17ms/step
# Epoch>1, Batch456/468, d1=0.046, d2=0.050 g=4.203
# 2/2 [==============================] - 0s 19ms/step
# Epoch>1, Batch457/468, d1=0.027, d2=0.049 g=4.254
# 2/2 [==============================] - 0s 27ms/step
# Epoch>1, Batch458/468, d1=0.280, d2=0.093 g=3.745
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch459/468, d1=0.149, d2=0.121 g=4.024
# 2/2 [==============================] - 0s 21ms/step
# Epoch>1, Batch460/468, d1=0.131, d2=0.076 g=4.129
# 2/2 [==============================] - 0s 29ms/step
# Epoch>1, Batch461/468, d1=0.091, d2=0.081 g=4.162
# 2/2 [==============================] - 0s 24ms/step
# Epoch>1, Batch462/468, d1=0.178, d2=0.141 g=4.007
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch463/468, d1=0.231, d2=0.092 g=4.146
# 2/2 [==============================] - 0s 15ms/step
# Epoch>1, Batch464/468, d1=0.201, d2=0.083 g=4.342
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch465/468, d1=0.050, d2=0.064 g=4.510
# 2/2 [==============================] - 0s 26ms/step
# Epoch>1, Batch466/468, d1=0.167, d2=0.141 g=4.318
# 2/2 [==============================] - 0s 16ms/step
# Epoch>1, Batch467/468, d1=0.090, d2=0.105 g=4.975
# 2/2 [==============================] - 0s 22ms/step
# Epoch>1, Batch468/468, d1=0.165, d2=0.119 g=5.092
# ...
# Epoch>10, Batch315/468, d1=0.519, d2=0.436 g=1.724
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch316/468, d1=0.457, d2=0.417 g=1.688
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch317/468, d1=0.536, d2=0.538 g=1.759
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch318/468, d1=0.449, d2=0.407 g=1.802
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch319/468, d1=0.494, d2=0.431 g=1.793
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch320/468, d1=0.509, d2=0.528 g=1.721
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch321/468, d1=0.404, d2=0.342 g=1.856
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch322/468, d1=0.552, d2=0.462 g=1.591
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch323/468, d1=0.574, d2=0.457 g=1.631
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch324/468, d1=0.364, d2=0.406 g=1.644
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch325/468, d1=0.531, d2=0.456 g=1.591
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch326/468, d1=0.427, d2=0.418 g=1.807
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch327/468, d1=0.607, d2=0.453 g=1.561
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch328/468, d1=0.562, d2=0.524 g=1.532
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch329/468, d1=0.446, d2=0.454 g=1.976
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch330/468, d1=0.498, d2=0.458 g=1.827
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch331/468, d1=0.597, d2=0.535 g=1.854
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch332/468, d1=0.484, d2=0.386 g=1.775
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch333/468, d1=0.499, d2=0.481 g=1.795
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch334/468, d1=0.538, d2=0.460 g=1.676
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch335/468, d1=0.472, d2=0.406 g=1.637
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch336/468, d1=0.470, d2=0.462 g=1.819
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch337/468, d1=0.529, d2=0.499 g=1.785
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch338/468, d1=0.389, d2=0.399 g=1.897
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch339/468, d1=0.558, d2=0.394 g=1.753
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch340/468, d1=0.574, d2=0.469 g=1.583
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch341/468, d1=0.536, d2=0.502 g=1.495
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch342/468, d1=0.430, d2=0.611 g=1.659
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch343/468, d1=0.464, d2=0.314 g=1.693
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch344/468, d1=0.518, d2=0.497 g=1.625
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch345/468, d1=0.443, d2=0.386 g=1.651
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch346/468, d1=0.519, d2=0.481 g=1.537
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch347/468, d1=0.480, d2=0.423 g=1.706
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch348/468, d1=0.401, d2=0.460 g=1.786
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch349/468, d1=0.464, d2=0.346 g=1.852
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch350/468, d1=0.468, d2=0.441 g=1.712
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch351/468, d1=0.498, d2=0.496 g=1.635
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch352/468, d1=0.482, d2=0.407 g=1.796
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch353/468, d1=0.533, d2=0.394 g=1.514
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch354/468, d1=0.473, d2=0.477 g=1.728
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch355/468, d1=0.409, d2=0.456 g=1.806
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch356/468, d1=0.614, d2=0.458 g=1.687
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch357/468, d1=0.456, d2=0.465 g=1.610
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch358/468, d1=0.481, d2=0.388 g=1.716
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch359/468, d1=0.553, d2=0.443 g=1.796
# 2/2 [==============================] - 0s 17ms/step
# Epoch>10, Batch360/468, d1=0.541, d2=0.540 g=1.816
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch361/468, d1=0.577, d2=0.448 g=1.543
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch362/468, d1=0.497, d2=0.525 g=1.615
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch363/468, d1=0.553, d2=0.515 g=1.708
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch364/468, d1=0.396, d2=0.463 g=1.839
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch365/468, d1=0.637, d2=0.486 g=1.729
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch366/468, d1=0.492, d2=0.512 g=1.858
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch367/468, d1=0.552, d2=0.392 g=1.739
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch368/468, d1=0.591, d2=0.418 g=1.566
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch369/468, d1=0.496, d2=0.481 g=1.514
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch370/468, d1=0.529, d2=0.613 g=1.700
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch371/468, d1=0.492, d2=0.415 g=1.884
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch372/468, d1=0.507, d2=0.421 g=1.686
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch373/468, d1=0.468, d2=0.415 g=1.709
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch374/468, d1=0.615, d2=0.500 g=1.588
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch375/468, d1=0.422, d2=0.394 g=1.603
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch376/468, d1=0.513, d2=0.423 g=1.660
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch377/468, d1=0.468, d2=0.441 g=1.723
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch378/468, d1=0.428, d2=0.459 g=1.694
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch379/468, d1=0.580, d2=0.460 g=1.676
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch380/468, d1=0.566, d2=0.520 g=1.541
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch381/468, d1=0.468, d2=0.471 g=1.696
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch382/468, d1=0.523, d2=0.432 g=1.682
# 2/2 [==============================] - 0s 17ms/step
# Epoch>10, Batch383/468, d1=0.586, d2=0.499 g=1.488
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch384/468, d1=0.548, d2=0.510 g=1.700
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch385/468, d1=0.402, d2=0.342 g=1.567
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch386/468, d1=0.511, d2=0.508 g=1.754
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch387/468, d1=0.534, d2=0.563 g=1.598
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch388/468, d1=0.544, d2=0.435 g=1.598
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch389/468, d1=0.612, d2=0.462 g=1.625
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch390/468, d1=0.477, d2=0.524 g=1.616
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch391/468, d1=0.396, d2=0.532 g=1.747
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch392/468, d1=0.447, d2=0.318 g=1.850
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch393/468, d1=0.611, d2=0.472 g=1.808
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch394/468, d1=0.404, d2=0.413 g=1.639
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch395/468, d1=0.474, d2=0.305 g=1.682
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch396/468, d1=0.413, d2=0.551 g=1.583
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch397/468, d1=0.416, d2=0.426 g=1.801
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch398/468, d1=0.496, d2=0.394 g=1.684
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch399/468, d1=0.476, d2=0.474 g=1.787
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch400/468, d1=0.509, d2=0.480 g=1.715
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch401/468, d1=0.513, d2=0.411 g=1.703
# 2/2 [==============================] - 0s 18ms/step
# Epoch>10, Batch402/468, d1=0.563, d2=0.416 g=1.518
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch403/468, d1=0.381, d2=0.433 g=1.807
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch404/468, d1=0.366, d2=0.407 g=1.859
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch405/468, d1=0.463, d2=0.353 g=1.741
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch406/468, d1=0.352, d2=0.333 g=1.828
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch407/468, d1=0.616, d2=0.420 g=1.553
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch408/468, d1=0.452, d2=0.415 g=1.630
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch409/468, d1=0.388, d2=0.428 g=1.756
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch410/468, d1=0.502, d2=0.396 g=1.598
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch411/468, d1=0.387, d2=0.400 g=1.715
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch412/468, d1=0.546, d2=0.483 g=1.879
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch413/468, d1=0.478, d2=0.401 g=1.799
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch414/468, d1=0.456, d2=0.467 g=1.735
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch415/468, d1=0.409, d2=0.423 g=1.835
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch416/468, d1=0.573, d2=0.328 g=1.742
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch417/468, d1=0.368, d2=0.415 g=1.749
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch418/468, d1=0.371, d2=0.368 g=1.737
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch419/468, d1=0.440, d2=0.374 g=1.721
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch420/468, d1=0.570, d2=0.391 g=1.568
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch421/468, d1=0.413, d2=0.485 g=1.618
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch422/468, d1=0.423, d2=0.404 g=1.611
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch423/468, d1=0.548, d2=0.449 g=1.864
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch424/468, d1=0.401, d2=0.342 g=1.881
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch425/468, d1=0.347, d2=0.438 g=1.827
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch426/468, d1=0.474, d2=0.402 g=1.923
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch427/468, d1=0.460, d2=0.392 g=1.815
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch428/468, d1=0.558, d2=0.445 g=1.833
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch429/468, d1=0.427, d2=0.439 g=1.800
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch430/468, d1=0.445, d2=0.400 g=1.716
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch431/468, d1=0.483, d2=0.355 g=1.635
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch432/468, d1=0.346, d2=0.372 g=1.668
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch433/468, d1=0.462, d2=0.472 g=1.784
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch434/468, d1=0.461, d2=0.416 g=1.745
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch435/468, d1=0.508, d2=0.410 g=1.740
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch436/468, d1=0.523, d2=0.416 g=1.597
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch437/468, d1=0.452, d2=0.478 g=1.732
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch438/468, d1=0.357, d2=0.377 g=1.688
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch439/468, d1=0.485, d2=0.435 g=1.913
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch440/468, d1=0.541, d2=0.490 g=1.619
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch441/468, d1=0.438, d2=0.425 g=1.904
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch442/468, d1=0.495, d2=0.370 g=1.550
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch443/468, d1=0.370, d2=0.388 g=1.808
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch444/468, d1=0.502, d2=0.393 g=1.631
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch445/468, d1=0.596, d2=0.426 g=1.535
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch446/468, d1=0.452, d2=0.507 g=1.636
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch447/468, d1=0.412, d2=0.454 g=1.868
# 2/2 [==============================] - 0s 13ms/step
# Epoch>10, Batch448/468, d1=0.417, d2=0.412 g=1.831
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch449/468, d1=0.531, d2=0.402 g=1.765
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch450/468, d1=0.529, d2=0.461 g=1.808
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Batch451/468, d1=0.440, d2=0.391 g=1.522
# 2/2 [==============================] - 0s 16ms/step
# Epoch>10, Batch452/468, d1=0.509, d2=0.410 g=1.659
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch453/468, d1=0.303, d2=0.481 g=1.679
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch454/468, d1=0.644, d2=0.450 g=1.651
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch455/468, d1=0.424, d2=0.383 g=1.709
# 2/2 [==============================] - 0s 14ms/step
# Epoch>10, Batch456/468, d1=0.519, d2=0.471 g=1.600
# 2/2 [==============================] - 0s 15ms/step
# Epoch>10, Bat
.1375321000814438, 0.16154929995536804, 0.1428331881761551, 0.2517520487308502, 0.1518392562866211, 0.2239837944507599, 0.5627565383911133, 0.22206570208072662, 0.37852776050567627, 0.3619272708892822, 0.5211049318313599, 0.6457901000976562, 0.221446231007576, 0.48435550928115845, 0.4172583818435669, 0.21811500191688538, 0.36687636375427246, 0.3451043367385864, 0.20108872652053833, 0.22771450877189636, 0.36668097972869873, 0.15718033909797668, 0.1542680561542511, 0.14442433416843414, 0.17132475972175598, 0.14751125872135162, 0.20100533962249756, 0.09832258522510529, 0.167259082198143, 0.11020173132419586, 0.07581941783428192, 0.08952011168003082, 0.07605477422475815, 0.10896102339029312, 0.056525811553001404, 0.06411654502153397, 0.08372865617275238, 0.07790003716945648, 0.038804791867733, 0.07391978055238724, 0.08234946429729462, 0.052378758788108826, 0.05144640803337097, 0.05832097679376602, 0.10828723758459091, 0.03857383131980896, 0.05980993062257767, 0.05594838783144951, 0.04433780908584595, 0.045269519090652466, 0.05332500487565994, 0.09334075450897217, 0.0486038476228714, 0.04896016791462898, 0.09326376020908356, 0.031413257122039795, 0.0648774579167366, 0.06954547017812729, 0.02981153130531311, 0.038596078753471375, 0.056221477687358856, 0.06387901306152344, 0.039641037583351135, 0.04179516062140465, 0.05728016048669815, 0.05336267128586769, 0.050926573574543, 0.03774251416325569, 0.04377730190753937, 0.05922248214483261, 0.05539707839488983, 0.0627366453409195, 0.11717691272497177, 0.06085668504238129, 0.039768464863300323, 0.09473086893558502, 0.04201256111264229, 0.10312201082706451, 0.0682639479637146, 0.04599988833069801, 0.12394000589847565, 0.08236603438854218, 0.04153843969106674, 0.18000023066997528, 0.10635483264923096, 0.1675730049610138, 0.13080823421478271, ...

# %%
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
import numpy as np
#

# %%
model = load_model(r"C:\Users\dhruv\Downloads\GAN_MNIST\CGan\mnist_conditional_generator_epochs.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
latent_points, labels = generate_latent_points(100, 100)
# specify labels - generate 10 sets of labels each gping from 0 to 9
labels = asarray([x for _ in range(10) for x in range(10)])
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

def show_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :, :])
	plt.show()
    
show_plot(X, 5)
# Out:
# 4/4 [==============================] - 0s 9ms/step

# %%
#save the h5 file of the model.
model_json = g_model.to_json()
with open("generator3.json", "w") as json_file:
    json_file.write(model_json)
g_model.save_weights('weights3.h5')
g_model.save('model3.h5')
g_model.save(r"C:\Users\dhruv\OneDrive\Desktop\images\model3.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model

# Load the trained generator model
generator = load_model(r"C:\Users\dhruv\Downloads\GAN_MNIST\CGan\mnist_conditional_generator_epochs.h5")

# Generate and plot sample images for each digit (0-9)
latent_dim = 100
n_samples_per_digit = 10

for digit in range(10):
    labels = np.full((n_samples_per_digit, 1), digit)
    latent_points = np.random.randn(n_samples_per_digit, latent_dim)
    generated_images = generator.predict([latent_points, labels])
    
    plt.figure(figsize=(10, 1))
    for i in range(n_samples_per_digit):
        plt.subplot(1, n_samples_per_digit, i + 1)
        plt.axis('off')
        plt.imshow(generated_images[i].reshape(28, 28), cmap='gray')

    plt.suptitle(f'Sample Images for Digit {digit}')
    plt.show()


discriminator_loss = d 
generator_loss = d2  
epochs = range(1, len(discriminator_loss) + 1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, discriminator_loss, label='Discriminator Loss')
plt.title('Discriminator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, generator_loss, label='Generator Loss')
plt.title('Generator Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
